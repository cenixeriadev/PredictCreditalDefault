# %% [markdown]
# <a href="https://colab.research.google.com/github/cenixeriadev/PredictCreditalDefault/blob/main/Loy/firstimpression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
b = 20

print (a+b)
# Out:
# 40

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  PredictCreditalDefault  sample_data

# %%
# !ls -la
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Jun  1 04:38 .
# drwxr-xr-x 1 root root 4096 Jun  1 03:53 ..
# drwxr-xr-x 4 root root 4096 May 26 13:25 .config
# drwx------ 5 root root 4096 Jun  1 04:38 drive
# drwxr-xr-x 4 root root 4096 Jun  1 04:39 PredictCreditalDefault
# drwxr-xr-x 1 root root 4096 May 26 13:25 sample_data

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/cenixeriadev/PredictCreditalDefault.git
# Out:
# Cloning into 'PredictCreditalDefault'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 4), reused 4 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 6.60 KiB | 965.00 KiB/s, done.
# Resolving deltas: 100% (4/4), done.
